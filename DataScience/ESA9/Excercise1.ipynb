# %% [markdown]
# <a href="https://colab.research.google.com/github/eqbic/OSMI/blob/main/DataScience/ESA9/Excercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

url = "https://raw.githubusercontent.com/eqbic/OSMI/main/DataScience/ESA9/BeerConsumption.csv"
beer_df = pd.read_csv(url, decimal=',', dtype={'Beer Consumption (liter' : np.float32})
beer_df.dropna(inplace=True)
beer_df.sort_values(by=['Temperature Average (C)'], inplace=True)

beer_df
# Out:
#            Data  Temperature Average (C)  ...  End of Week  Beer Consumption (liter)
# 185  2015-07-05                    12.90  ...          1.0                    21.294
# 254  2015-09-12                    14.00  ...          1.0                    21.814
# 255  2015-09-13                    14.18  ...          1.0                    21.252
# 202  2015-07-22                    14.52  ...          0.0                    14.343
# 174  2015-06-24                    14.54  ...          0.0                    17.241
# ..          ...                      ...  ...          ...                       ...
# 8    2015-01-09                    28.20  ...          0.0                    24.886
# 18   2015-01-19                    28.22  ...          0.0                    29.265
# 17   2015-01-18                    28.26  ...          1.0                    30.524
# 266  2015-09-24                    28.30  ...          0.0                    30.345
# ...

# %%
# convert panda series to numpy arrays
temps = beer_df['Temperature Average (C)'].to_numpy(dtype=np.float32)
beer_consumption = beer_df['Beer Consumption (liter)'].to_numpy(dtype=np.float32)
plt.figure(figsize=(20,10))
plt.scatter(temps, beer_consumption)

# %%
model = np.polyfit(temps, beer_consumption, 1)
predict = np.poly1d(model)
x_predict = range(13, 30)
y_predict = predict(x_predict)

plt.figure(figsize=(20,10))
plt.scatter(temps, beer_consumption)
plt.plot(x_predict, y_predict, c='r')
